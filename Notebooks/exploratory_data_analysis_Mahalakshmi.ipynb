# %%
# %run ../Notebooks/data_processing_newData.ipynb
# Out:
# ['D:\\uOttawa\\Smart Cities\\Research Project\\smart-grid-predictors\\Notebooks', 'C:\\Users\\Mahalakshmi Muthuvel\\AppData\\Local\\Programs\\Python\\Python312\\python312.zip', 'C:\\Users\\Mahalakshmi Muthuvel\\AppData\\Local\\Programs\\Python\\Python312\\DLLs', 'C:\\Users\\Mahalakshmi Muthuvel\\AppData\\Local\\Programs\\Python\\Python312\\Lib', 'C:\\Users\\Mahalakshmi Muthuvel\\AppData\\Local\\Programs\\Python\\Python312', 'D:\\uOttawa\\Smart Cities\\Research Project\\smart-grid-predictors\\ml_env', '', 'D:\\uOttawa\\Smart Cities\\Research Project\\smart-grid-predictors\\ml_env\\Lib\\site-packages', 'D:\\uOttawa\\Smart Cities\\Research Project\\smart-grid-predictors\\ml_env\\Lib\\site-packages\\win32', 'D:\\uOttawa\\Smart Cities\\Research Project\\smart-grid-predictors\\ml_env\\Lib\\site-packages\\win32\\lib', 'D:\\uOttawa\\Smart Cities\\Research Project\\smart-grid-predictors\\ml_env\\Lib\\site-packages\\Pythonwin', 'D:\\uOttawa\\Smart Cities\\Research Project\\smart-grid-predictor
# ...

# %%
merged_df
# Out:
#       Longitude (x)  Latitude (y)   Station Name  Climate ID  \
# 0            -75.67         45.32  OTTAWA INTL A     6106001
# 1            -75.67         45.32  OTTAWA INTL A     6106001
# 2            -75.67         45.32  OTTAWA INTL A     6106001
# 3            -75.67         45.32  OTTAWA INTL A     6106001
# 4            -75.67         45.32  OTTAWA INTL A     6106001
# ...             ...           ...            ...         ...
# 8751         -75.67         45.32  OTTAWA INTL A     6106001
# 8752         -75.67         45.32  OTTAWA INTL A     6106001
# 8753         -75.67         45.32  OTTAWA INTL A     6106001
# 8754         -75.67         45.32  OTTAWA INTL A     6106001
# 8755         -75.67         45.32  OTTAWA INTL A     6106001
#
#                 DateTime  Year  Month  Day Time (LST)  Temp (°C)  Temp Flag  \
# 0    2023-01-01 00:00:00  2023      1    1      00:00        3.0        NaN
# 1    2023-01-01 01:00:00  2023      1    1      01:00        3.0        NaN
# ...

# %%
merged_df.columns
# Out:
# Index(['Longitude (x)', 'Latitude (y)', 'Station Name', 'Climate ID',
#        'DateTime', 'Year', 'Month', 'Day', 'Time (LST)', 'Temp (°C)',
#        'Temp Flag', 'Dew Point Temp (°C)', 'Dew Point Temp Flag',
#        'Rel Hum (%)', 'Rel Hum Flag', 'Precip. Amount (mm)',
#        'Precip. Amount Flag', 'Wind Dir (10s deg)', 'Wind Dir Flag',
#        'Wind Spd (km/h)', 'Wind Spd Flag', 'Visibility (km)',
#        'Visibility Flag', 'Stn Press (kPa)', 'Stn Press Flag', 'Hmdx',
#        'Hmdx Flag', 'Wind Chill', 'Wind Chill Flag', 'Weather',
#        'Meter Reading (KWHr)'],
#       dtype='object')

# %%
import matplotlib.pyplot as plt
import seaborn as sns


# Create a box plot
sns.boxplot(x=merged_df['Wind Dir (10s deg)'])

# Add title and labels
plt.title('Box Plot of ' + 'Wind Dir (10s deg)')
plt.xlabel('Wind Dir (10s deg)')

# Show the plot
plt.show()

# %%
sns.heatmap(df)
# Out:
# <Axes: >

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Create scatter plot
plt.scatter(merged_df['Month'], merged_df['Meter Reading (KWHr)'])

# Add labels and title
plt.xlabel('Month')
plt.ylabel('Meter Reading (KWHr)')
plt.title('Scatter Plot of Month vs Meter Reading (KWHr)')

# Display the plot
plt.show()
